# %%
from matplotlib import pyplot as plt
from sklearn.datasets import load_digits

# %%
dig = load_digits()

# %%
dir(dig)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
dig.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
dig.feature_names
# Out:
# ['pixel_0_0',
#  'pixel_0_1',
#  'pixel_0_2',
#  'pixel_0_3',
#  'pixel_0_4',
#  'pixel_0_5',
#  'pixel_0_6',
#  'pixel_0_7',
#  'pixel_1_0',
#  'pixel_1_1',
#  'pixel_1_2',
#  'pixel_1_3',
#  'pixel_1_4',
#  'pixel_1_5',
#  'pixel_1_6',
#  'pixel_1_7',
#  'pixel_2_0',
#  'pixel_2_1',
#  'pixel_2_2',
#  'pixel_2_3',
#  'pixel_2_4',
#  'pixel_2_5',
#  'pixel_2_6',
#  'pixel_2_7',
#  'pixel_3_0',
#  'pixel_3_1',
#  'pixel_3_2',
#  'pixel_3_3',
#  'pixel_3_4',
#  'pixel_3_5',
#  'pixel_3_6',
#  'pixel_3_7',
#  'pixel_4_0',
#  'pixel_4_1',
#  'pixel_4_2',
#  'pixel_4_3',
#  'pixel_4_4',
#  'pixel_4_5',
#  'pixel_4_6',
#  'pixel_4_7',
#  'pixel_5_0',
#  'pixel_5_1',
#  'pixel_5_2',
#  'pixel_5_3',
#  'pixel_5_4',
#  'pixel_5_5',
#  'pixel_5_6',
#  'pixel_5_7',
#  'pixel_6_0',
#  'pixel_6_1',
#  'pixel_6_2',
#  'pixel_6_3',
#  'pixel_6_4',
#  'pixel_6_5',
#  'pixel_6_6',
#  'pixel_6_7',
#  'pixel_7_0',
#  'pixel_7_1',
#  'pixel_7_2',
#  'pixel_7_3',
#  'pixel_7_4',
#  'pixel_7_5',
#  'pixel_7_6',
#  'pixel_7_7']

# %%
dig.images
# Out:
# array([[[ 0.,  0.,  5., ...,  1.,  0.,  0.],
#         [ 0.,  0., 13., ..., 15.,  5.,  0.],
#         [ 0.,  3., 15., ..., 11.,  8.,  0.],
#         ...,
#         [ 0.,  4., 11., ..., 12.,  7.,  0.],
#         [ 0.,  2., 14., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  6., ...,  0.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ...,  5.,  0.,  0.],
#         [ 0.,  0.,  0., ...,  9.,  0.,  0.],
#         [ 0.,  0.,  3., ...,  6.,  0.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  3., ..., 14.,  0.,  0.],
#         [ 0.,  0.,  8., ..., 16.,  0.,  0.],
#         ...,
#         [ 0.,  9., 16., ...,  0.,  0.,  0.],
#         [ 0.,  3., 13., ..., 11.,  5.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.]],
#
#        ...,
#
#        [[ 0.,  0.,  1., ...,  1.,  0.,  0.],
#         [ 0.,  0., 13., ...,  2.,  1.,  0.],
#         [ 0.,  0., 16., ..., 16.,  5.,  0.],
#         ...,
#         [ 0.,  0., 16., ..., 15.,  0.,  0.],
#         [ 0.,  0., 15., ..., 16.,  0.,  0.],
#         [ 0.,  0.,  2., ...,  6.,  0.,  0.]],
#
#        [[ 0.,  0.,  2., ...,  0.,  0.,  0.],
#         [ 0.,  0., 14., ..., 15.,  1.,  0.],
#         [ 0.,  4., 16., ..., 16.,  7.,  0.],
#         ...,
#         [ 0.,  0.,  0., ..., 16.,  2.,  0.],
#         [ 0.,  0.,  4., ..., 16.,  2.,  0.],
#         [ 0.,  0.,  5., ..., 12.,  0.,  0.]],
#
#        [[ 0.,  0., 10., ...,  1.,  0.,  0.],
#         [ 0.,  2., 16., ...,  1.,  0.,  0.],
#         [ 0.,  0., 15., ..., 15.,  0.,  0.],
#         ...,
#         [ 0.,  4., 16., ..., 16.,  6.,  0.],
#         [ 0.,  8., 16., ..., 16.,  8.,  0.],
#         [ 0.,  1.,  8., ..., 12.,  1.,  0.]]])

# %%
plt.imshow(dig.images[0])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dig.data, dig.target, test_size=0.2)

# %%
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([5, 9, 3, 0, 3, 9, 4, 6, 0, 1, 1, 3, 6, 6, 4, 1, 7, 9, 0, 7, 7, 5,
#        0, 3, 7, 1, 7, 8, 0, 6, 1, 2, 9, 8, 7, 7, 2, 9, 3, 2, 3, 0, 1, 3,
#        7, 5, 0, 1, 8, 1, 1, 1, 0, 6, 0, 1, 5, 6, 5, 1, 8, 6, 7, 0, 8, 5,
#        4, 8, 6, 8, 2, 7, 7, 0, 5, 3, 2, 8, 0, 0, 9, 5, 7, 1, 5, 2, 3, 3,
#        7, 9, 8, 4, 5, 0, 8, 5, 7, 9, 2, 3, 9, 5, 3, 0, 3, 9, 7, 9, 5, 9,
#        6, 1, 2, 9, 8, 9, 2, 1, 1, 9, 5, 4, 4, 9, 9, 8, 7, 5, 8, 0, 3, 9,
#        9, 6, 9, 0, 2, 2, 1, 7, 6, 7, 3, 2, 4, 0, 5, 1, 7, 3, 3, 6, 1, 5,
#        6, 0, 7, 1, 4, 9, 2, 6, 0, 5, 0, 9, 6, 0, 0, 8, 9, 1, 6, 9, 5, 4,
#        7, 5, 1, 8, 5, 2, 6, 0, 6, 8, 5, 6, 4, 9, 8, 0, 0, 0, 6, 9, 8, 7,
#        3, 8, 3, 5, 0, 6, 6, 9, 1, 9, 1, 4, 7, 9, 7, 5, 7, 3, 9, 7, 3, 4,
#        7, 9, 1, 1, 0, 3, 4, 2, 9, 5, 4, 7, 0, 7, 2, 4, 6, 9, 9, 0, 7, 2,
#        7, 2, 6, 1, 4, 5, 3, 8, 1, 1, 7, 0, 4, 4, 9, 4, 4, 4, 2, 5, 0, 6,
#        9, 3, 4, 1, 8, 1, 6, 3, 6, 4, 0, 6, 0, 8, 0, 7, 6, 9, 8, 9, 5, 6,
#        6, 3, 2, 2, 9, 6, 5, 6, 3, 2, 8, 8, 3, 9, 0, 7, 8, 1, 5, 1, 7, 9,
#        8, 1, 4, 4, 4, 7, 1, 3, 2, 8, 6, 4, 2, 0, 8, 0, 7, 6, 0, 9, 1, 8,
#        9, 7, 5, 8, 6, 2, 8, 7, 3, 6, 3, 5, 3, 7, 2, 9, 4, 5, 5, 0, 7, 2,
#        1, 0, 2, 2, 1, 5, 8, 3])

# %%
y_test
# Out:
# array([5, 9, 3, 0, 3, 9, 4, 6, 0, 1, 8, 3, 6, 6, 4, 1, 7, 9, 0, 7, 7, 5,
#        0, 3, 7, 1, 7, 8, 0, 6, 1, 2, 9, 8, 7, 7, 2, 9, 3, 2, 3, 0, 1, 3,
#        7, 5, 0, 1, 8, 1, 1, 1, 0, 6, 0, 1, 5, 6, 5, 1, 8, 6, 7, 0, 8, 5,
#        4, 8, 6, 8, 2, 7, 7, 0, 5, 3, 2, 8, 0, 0, 9, 5, 7, 1, 5, 2, 3, 3,
#        7, 9, 8, 4, 5, 0, 8, 5, 7, 9, 2, 3, 9, 5, 3, 0, 3, 9, 7, 9, 5, 9,
#        6, 1, 2, 9, 9, 9, 2, 2, 1, 9, 5, 4, 4, 9, 9, 8, 7, 5, 8, 0, 3, 9,
#        9, 6, 9, 0, 2, 2, 1, 7, 6, 7, 3, 2, 4, 0, 5, 8, 7, 3, 3, 6, 1, 5,
#        6, 0, 7, 1, 4, 9, 2, 6, 0, 5, 0, 9, 6, 0, 0, 8, 9, 1, 6, 5, 5, 4,
#        7, 5, 8, 8, 5, 2, 6, 0, 6, 8, 5, 6, 4, 9, 8, 0, 0, 0, 6, 9, 8, 7,
#        3, 8, 3, 8, 0, 6, 6, 9, 1, 9, 1, 4, 7, 9, 7, 5, 7, 3, 9, 7, 3, 4,
#        7, 9, 1, 1, 0, 3, 4, 2, 9, 5, 4, 7, 0, 7, 2, 4, 6, 9, 9, 0, 7, 2,
#        7, 2, 6, 1, 4, 5, 3, 8, 1, 1, 7, 0, 4, 4, 9, 4, 4, 4, 2, 5, 0, 6,
#        9, 3, 4, 1, 8, 1, 6, 3, 6, 4, 0, 6, 0, 8, 0, 7, 6, 9, 8, 9, 5, 6,
#        6, 3, 2, 2, 9, 6, 5, 6, 3, 2, 8, 8, 3, 9, 0, 7, 8, 1, 5, 2, 7, 9,
#        8, 1, 4, 4, 7, 7, 1, 3, 2, 8, 6, 4, 2, 0, 8, 0, 7, 6, 0, 9, 1, 8,
#        5, 8, 5, 8, 6, 2, 8, 7, 3, 6, 3, 5, 3, 7, 2, 9, 4, 5, 5, 0, 7, 2,
#        1, 0, 2, 2, 1, 5, 8, 3])

# %%
model.score(X_test,y_test)
# Out:
# 0.9694444444444444
